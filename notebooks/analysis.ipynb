# %% [markdown]
# # Phishing Website Detection - Exploratory Analysis
#
# This notebook provides a brief exploratory analysis of the phishing dataset and demonstrates how to use the preprocessing and modeling utilities from the `src` package.
#
# ## Contents
# - Load the dataset
# - Inspect basic structure and class balance
# - Run the preprocessing pipeline
# - Train a simple baseline model and inspect evaluation metrics
